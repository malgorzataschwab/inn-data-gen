# %% [markdown]
# ## Invertible Neural Net for Synthetic Data Generation
# * **Case study**: MNIST data generation
# * **Authors**: Malgorzata Schwab and Ashis Kumer Biswas

# %% [markdown]
# ### The Imports

# %%
import torch
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from functionalities import dataloader as dl
from functionalities import gpu
from utils import train_bottleneck

# Ref of the following FrEIA framework is from https://github.com/vislearn/FrEIA
from FrEIA import framework as fr
from FrEIA.modules import coeff_functs as fu
from FrEIA.modules import coupling_layers as la
from FrEIA.modules import reshapes as re

# %% [markdown]
# ### The invertible Autoencoder

# %%
def mnist_inn_com(mask_size=[28, 28]):
    """
    Return an autoencoder.

    :param mask_size: size of the input. Default: Size of MNIST images
    :return:
    """

    img_dims = [1, mask_size[0], mask_size[1]]

    inp = fr.InputNode(*img_dims, name='input')

    r1 = fr.Node([inp.out0], re.haar_multiplex_layer, {}, name='r1')

    conv1 = fr.Node([r1.out0], la.glow_coupling_layer, {'F_class': fu.F_conv,
                    'F_args': {'channels_hidden': 100}, 'clamp': 1}, name='conv1')

    conv2 = fr.Node([conv1.out0], la.glow_coupling_layer, {'F_class': fu.F_conv,
                    'F_args': {'channels_hidden': 100}, 'clamp': 1}, name='conv2')

    conv3 = fr.Node([conv2.out0], la.glow_coupling_layer, {'F_class': fu.F_conv,
                    'F_args': {'channels_hidden': 100}, 'clamp': 1}, name='conv3')

    r2 = fr.Node([conv3.out0], re.reshape_layer, {'target_dim': (img_dims[0]*img_dims[1]*img_dims[2],)}, name='r2')

    fc = fr.Node([r2.out0], la.rev_multiplicative_layer, {'F_class': fu.F_small_connected, 'F_args': {'internal_size': 180}, 'clamp': 1}, name='fc')

    r3 = fr.Node([fc.out0], re.reshape_layer, {'target_dim': (4, 14, 14)}, name='r3')

    r4 = fr.Node([r3.out0], re.haar_restore_layer, {}, name='r4')

    outp = fr.OutputNode([r4.out0], name='output')

    nodes = [inp, outp, conv1, conv2, conv3, r1, r2, r3, r4, fc]

    coder = fr.ReversibleGraphNet(nodes, 0, 1)

    return coder

# %% [markdown]
# ### Setting the Hyperparameters

# %%
### Pretraining Setup
num_epoch = 10
batch_size = 128

#this is also called the bottleneck size
latent_dim_lst = [4] #[8, 16, 64]  #[1, 2, 3, 4, 6, 8, 12, 16, 24, 32, 48, 64]

number_dev = 0 #device id

lr_init = 1e-3 #initial learning rate
l2_reg  = 1e-6 #weight decay

milestones = [4] #[8, 10] #at which epoch the lr would be reduced

#save model file name (in the variables/ and models/ directory)
modelname = 'mnist_INN_glow_com_bottleneck'

#the function which returns an INN. 
# In this case the mnist_inn_com returns an INN-Autoencoder
get_model = mnist_inn_com

#device name where training will be performed
device = gpu.get_device(number_dev)
print(f'The training is possible to run in {device}')
# Out:
# The training is possible to run in cuda

# %% [markdown]
# ### The dataset and the `DataLoader`s

# %%
#The MNIST dataset
trainset, testset, classes = dl.load_mnist() 

#Corresponding dataloaders
trainloader, validloader, testloader = dl.make_dataloaders(trainset, testset, batch_size)

# %% [markdown]
# ### The training loop

# %%
### Training INN as Autoencoder
model = train_bottleneck(num_epoch=num_epoch, #num of training epochs
                         get_model=get_model, #function returning INN that should be trained
                         loss_type='l1', #reconstruction loss considered
                         milestones = milestones, #list of training epochs where learning rate (lr) is reduced
                         latent_dim_lst = latent_dim_lst, #list of latent dims
                         trainloader = trainloader, #training data loader
                         validloader = None, #validation data loader
                         testloader = testloader, #test dataloader
                         a_distr=0, #factor for distribution loss
                         a_disen=0, #factor for reconstruction loss
                         lr_init=lr_init, #initial lr to begin with
                         l2_reg=l2_reg, #weight decay
                         device=device, #device to use for training
                         save_model=True, #save model?
                         modelname = modelname, #filename of the saved model
                        )
# Out:
# TRAIN BOTTLENECK
#
#
# Start Training with latent dimension: 4
#
#
# Node r1 has following input dimensions:
# 	 Output #0 of node input: (1, 28, 28)
#
# Node conv1 has following input dimensions:
# 	 Output #0 of node r1: (4, 14, 14)
#
# Node conv2 has following input dimensions:
# 	 Output #0 of node conv1: (4, 14, 14)
#
# Node conv3 has following input dimensions:
# 	 Output #0 of node conv2: (4, 14, 14)
#
# Node r2 has following input dimensions:
# 	 Output #0 of node conv3: (4, 14, 14)
#
# internal_size: 180
# internal_size: 180
# internal_size: 180
# internal_size: 180
# Node fc has following input dimensions:
# 	 Output #0 of node r2: (784,)
#
# Node r3 has following input dimensions:
# 	 Output #0 of node fc: (784,)
#
# Node r4 has following input dimensions:
# 	 Output #0 of node r3: (4, 14, 14)
#
# Node output has following input dimensions:
# 	 Output #0 of node r4: (1, 28, 28)
#
# after init_model
# after init_training
# TRAIN
# conditonal= False
# length of losses: 5
# Epoch: 1
# Training:
#   0%|          | 0/468 [00:00<?, ?it/s]
# Loss: 0.126 	 L_rec: 0.122 	 L_dist: 0.000 	 L_spar: 0.004 	 L_disen: 0.000
#
#
# Compute and record loss on test set:
# EVAL
# conditonal= False
# device= cuda
#   0%|          | 0/78 [00:00<?, ?it/s]
# Loss: 0.111 	 L_rec: 0.110 	 L_dist: 0.000 	 L_spar: 0.001 	 L_disen: 0.000
# latent image mean: -0.019 	 latent image std: 0.096
# Original Image:
# Reconstructed Image:
# Difference:
# --------------------------------------------------------------------------------
#
#
# length of losses: 5
# Epoch: 2
# Training:
#   0%|          | 0/468 [00:00<?, ?it/s]
# Loss: 0.100 	 L_rec: 0.099 	 L_dist: 0.000 	 L_spar: 0.001 	 L_disen: 0.000
#
#
# Compute and record loss on test set:
# EVAL
# conditonal= False
# device= cuda
#   0%|          | 0/78 [00:00<?, ?it/s]
# Loss: 0.087 	 L_rec: 0.086 	 L_dist: 0.000 	 L_spar: 0.001 	 L_disen: 0.000
# latent image mean: -0.030 	 latent image std: 0.138
#
#
# --------------------------------------------------------------------------------
#
#
# length of losses: 5
# Epoch: 3
# Training:
#   0%|          | 0/468 [00:00<?, ?it/s]
# Loss: 0.081 	 L_rec: 0.080 	 L_dist: 0.000 	 L_spar: 0.001 	 L_disen: 0.000
#
#
# Compute and record loss on test set:
# EVAL
# conditonal= False
# device= cuda
#   0%|          | 0/78 [00:00<?, ?it/s]
# Loss: 0.076 	 L_rec: 0.076 	 L_dist: 0.000 	 L_spar: 0.001 	 L_disen: 0.000
# latent image mean: -0.030 	 latent image std: 0.147
#
#
# --------------------------------------------------------------------------------
#
#
# length of losses: 5
# Epoch: 4
# Training:
#   0%|          | 0/468 [00:00<?, ?it/s]
# Loss: 0.074 	 L_rec: 0.073 	 L_dist: 0.000 	 L_spar: 0.001 	 L_disen: 0.000
#
#
# Compute and record loss on test set:
# EVAL
# conditonal= False
# device= cuda
#   0%|          | 0/78 [00:00<?, ?it/s]
# Loss: 0.073 	 L_rec: 0.072 	 L_dist: 0.000 	 L_spar: 0.001 	 L_disen: 0.000
# latent image mean: -0.025 	 latent image std: 0.134
#
#
# --------------------------------------------------------------------------------
#
#
# length of losses: 5
# Epoch: 5
# Training:
#   0%|          | 0/468 [00:00<?, ?it/s]
# Loss: 0.073 	 L_rec: 0.072 	 L_dist: 0.000 	 L_spar: 0.001 	 L_disen: 0.000
#
#
# Compute and record loss on test set:
# EVAL
# conditonal= False
# device= cuda
#   0%|          | 0/78 [00:00<?, ?it/s]
# Loss: 0.072 	 L_rec: 0.072 	 L_dist: 0.000 	 L_spar: 0.000 	 L_disen: 0.000
# latent image mean: -0.027 	 latent image std: 0.131
#
#
# --------------------------------------------------------------------------------
#
#
# length of losses: 5
# Epoch: 6
# Training:
#   0%|          | 0/468 [00:00<?, ?it/s]
# Loss: 0.072 	 L_rec: 0.071 	 L_dist: 0.000 	 L_spar: 0.000 	 L_disen: 0.000
#
#
# Compute and record loss on test set:
# EVAL
# conditonal= False
# device= cuda
#   0%|          | 0/78 [00:00<?, ?it/s]
# Loss: 0.071 	 L_rec: 0.071 	 L_dist: 0.000 	 L_spar: 0.000 	 L_disen: 0.000
# latent image mean: -0.026 	 latent image std: 0.130
#
#
# --------------------------------------------------------------------------------
#
#
# length of losses: 5
# Epoch: 7
# Training:
#   0%|          | 0/468 [00:00<?, ?it/s]
# Loss: 0.071 	 L_rec: 0.071 	 L_dist: 0.000 	 L_spar: 0.000 	 L_disen: 0.000
#
#
# Compute and record loss on test set:
# EVAL
# conditonal= False
# device= cuda
#   0%|          | 0/78 [00:00<?, ?it/s]
# Loss: 0.071 	 L_rec: 0.071 	 L_dist: 0.000 	 L_spar: 0.000 	 L_disen: 0.000
# latent image mean: -0.026 	 latent image std: 0.129
#
#
# --------------------------------------------------------------------------------
#
#
# length of losses: 5
# Epoch: 8
# Training:
#   0%|          | 0/468 [00:00<?, ?it/s]
# Loss: 0.071 	 L_rec: 0.070 	 L_dist: 0.000 	 L_spar: 0.000 	 L_disen: 0.000
#
#
# Compute and record loss on test set:
# EVAL
# conditonal= False
# device= cuda
#   0%|          | 0/78 [00:00<?, ?it/s]
# Loss: 0.070 	 L_rec: 0.070 	 L_dist: 0.000 	 L_spar: 0.000 	 L_disen: 0.000
# latent image mean: -0.025 	 latent image std: 0.127
#
#
# --------------------------------------------------------------------------------
#
#
# length of losses: 5
# Epoch: 9
# Training:
#   0%|          | 0/468 [00:00<?, ?it/s]
# Loss: 0.070 	 L_rec: 0.070 	 L_dist: 0.000 	 L_spar: 0.000 	 L_disen: 0.000
#
#
# Compute and record loss on test set:
# EVAL
# conditonal= False
# device= cuda
#   0%|          | 0/78 [00:00<?, ?it/s]
# Loss: 0.070 	 L_rec: 0.069 	 L_dist: 0.000 	 L_spar: 0.000 	 L_disen: 0.000
# latent image mean: -0.024 	 latent image std: 0.128
#
#
# --------------------------------------------------------------------------------
#
#
# length of losses: 5
# Epoch: 10
# Training:
#   0%|          | 0/468 [00:00<?, ?it/s]
# Loss: 0.070 	 L_rec: 0.069 	 L_dist: 0.000 	 L_spar: 0.000 	 L_disen: 0.000
#
#
# Compute and record loss on test set:
# EVAL
# conditonal= False
# device= cuda
#   0%|          | 0/78 [00:00<?, ?it/s]
# Loss: 0.069 	 L_rec: 0.069 	 L_dist: 0.000 	 L_spar: 0.000 	 L_disen: 0.000
# latent image mean: -0.023 	 latent image std: 0.129
# Original Image:
# Reconstructed Image:
# Difference:
# --------------------------------------------------------------------------------
#
#
# Finished Training
# conditonal= False
#
#
# ################################################################################
# ################################################################################

# %% [markdown]
# ### Printing model architecture

# %%
print(model)
# Out:
# ReversibleGraphNet(
#   (module_list): ModuleList(
#     (0): None
#     (1): dummy()
#     (2-4): 3 x glow_coupling_layer(
#       (s1): F_conv(
#         (conv1): Conv2d(2, 100, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (conv2): Conv2d(100, 100, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (conv3): Conv2d(100, 4, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (s2): F_conv(
#         (conv1): Conv2d(2, 100, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (conv2): Conv2d(100, 100, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (conv3): Conv2d(100, 4, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (5): haar_multiplex_layer()
#     (6-7): 2 x reshape_layer()
#     (8): haar_restore_layer()
#     (9): rev_multiplicative_layer(
#       (s1): F_small_connected(
#         (d1): Dropout(p=0.0, inplace=False)
#         (fc1): Linear(in_features=392, out_features=180, bias=True)
#         (fc3): Linear(in_features=180, out_features=392, bias=True)
#         (nl1): ReLU()
#       )
#       (t1): F_small_connected(
#         (d1): Dropout(p=0.0, inplace=False)
#         (fc1): Linear(in_features=392, out_features=180, bias=True)
#         (fc3): Linear(in_features=180, out_features=392, bias=True)
#         (nl1): ReLU()
#       )
#       (s2): F_small_connected(
#         (d1): Dropout(p=0.0, inplace=False)
#         (fc1): Linear(in_features=392, out_features=180, bias=True)
#         (fc3): Linear(in_features=180, out_features=392, bias=True)
#         (nl1): ReLU()
#       )
#       (t2): F_small_connected(
#         (d1): Dropout(p=0.0, inplace=False)
#         (fc1): Linear(in_features=392, out_features=180, bias=True)
#         (fc3): Linear(in_features=180, out_features=392, bias=True)
#         (nl1): ReLU()
#       )
#     )
#   )
# )

# %% [markdown]
# ### Generating Synthetic data with the INN Autoencoder model

# %%
## Replacing latent input with noise
## Artificial bottleneck
batch_size = 128
latent_dim = 4
input_size = 784
x_rnd = torch.rand(batch_size, 1, 28, 28)
x_rnd_shape = x_rnd.shape


lat_samples = np.random.normal(loc = 0, scale = 1, size=(batch_size, latent_dim))
zero_samples = np.zeros(shape=(batch_size, input_size - latent_dim))
samples = np.concatenate((lat_samples, zero_samples), axis=1)
print("sample:\n", samples[0:20, 0:4]) # sample:  [-0.56294419 -0.88707191  0.          0.          0.          0.
print("samples shape: ", samples.shape)

# Entire 784 is random
# samples = np.random.normal(size=(batch_size, input_size))
samples_torch = torch.from_numpy(samples)
x_rnd = (samples_torch.view(x_rnd_shape)).float()

# Generation is in the reverse flow
x_gen = model(x_rnd, rev=True)

# Visualize
x_img = x_rnd.detach().numpy()
#zy_img = zy_new.detach().numpy()
x_gen_img = x_gen.detach().numpy()

fig = plt.figure(figsize=(4, 4))

for idx in np.arange(20):
    ax=fig.add_subplot(4, 5, idx + 1, fc = (0,0,0,idx/(20+2)), xticks=[], yticks=[])
    ax.imshow(x_gen_img[idx].reshape(28,28), cmap='gray')
# Out:
# sample:
#  [[ 1.21658039e+00  1.75753866e+00 -7.79712285e-01  1.03306360e-01]
#  [-1.09583173e+00 -8.01496160e-01  3.75947590e-02 -1.92949239e+00]
#  [-4.10753224e-02 -6.72826318e-01  8.24711932e-02 -1.51274379e+00]
#  [-1.61817670e+00 -4.14668837e-01  1.07628762e+00 -1.18446676e+00]
#  [-6.91384328e-01  6.00642680e-03  1.83787463e+00 -5.64562437e-02]
#  [ 3.99537116e-02 -8.01409276e-01  2.37008687e-01  8.23801110e-01]
#  [ 1.36640852e+00  9.08216599e-01 -4.29999530e-01  1.07553295e+00]
#  [ 5.27635166e-01  1.13546227e-01 -7.39023075e-01  7.76947431e-01]
#  [-8.45630788e-01 -5.87771269e-01 -5.68868077e-01 -9.72189406e-01]
#  [-5.89563869e-01 -9.73026741e-01 -3.90200071e-02 -3.34082211e-01]
#  [-1.27489598e-01 -1.11668979e+00  1.11071849e+00 -4.14716247e-01]
#  [ 1.52255397e+00  4.87271926e-01  6.90909464e-01 -6.36660024e-01]
#  [ 1.28743297e+00  3.85140978e-01  5.98364126e-01  1.04361673e+00]
#  [-1.57890884e-02  2.33006440e-01  7.46419783e-01  4.41493402e-01]
#  [-7.28732592e-01  1.78551672e-01 -8.92754358e-02 -1.07964347e+00]
#  [-2.98510703e-01  5.90770114e-01 -4.63417532e-01  2.06231027e+00]
#  [ 5.00942543e-01  4.15216531e-01 -5.34750797e-01  1.46203193e+00]
#  [ 1.59837717e+00  9.97211845e-04 -2.15380311e-01  1.13837272e-01]
#  [-2.15811688e+00  9.95440132e-02  9.94375468e-01 -9.76093906e-01]
#  [ 3.46584175e-01 -9.87832457e-01 -3.02141934e-01 -4.85452477e-01]]
# samples shape:  (128, 784)
